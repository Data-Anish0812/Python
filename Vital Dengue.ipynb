# %%
pip install customtkinter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fpdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tkinter as tk
import customtkinter as ctk

# %%
ctk.set_appearance_mode('Dark')
ctk.set_default_color_theme('green')
window=ctk.CTk()

title_label=ctk.CTkLabel(window,text='Vital Dengue',font=('Arinal',29,'bold')) # Healthy life hospital
title_label.place(relx=0.4,rely=0.05)

name_label=ctk.CTkLabel(window,text='Patient Name',font=('Arinal',16,'bold'))
name_label.place(relx=0.2,rely=0.25)

name_entry=ctk.CTkEntry(window,width=180)
name_entry.place(relx=0.3,rely=0.25)

age_label=ctk.CTkLabel(window,text='Patient Age',font=('Arinal',16,'bold'))
age_label.place(relx=0.2,rely=0.35)

age_entry=ctk.CTkEntry(window,width=180)
age_entry.place(relx=0.3,rely=0.35)

fever_label=ctk.CTkLabel(window,text='Fever (C)',font=('Arinal',16,'bold'))
fever_label.place(relx=0.2,rely=0.55)

fever_entry=ctk.CTkEntry(window,width=180)
fever_entry.place(relx=0.3,rely=0.55)

gender_label=ctk.CTkLabel(window,text='Gender',font=('Arinal',16,'bold'))
gender_label.place(relx=0.2,rely=0.45)  

gender_entry=ctk.CTkEntry(window,width=180)
gender_entry.place(relx=0.3,rely=0.45)

headache_label=ctk.CTkLabel(window,text='Headache (Yes/No)',font=('Arinal',16,'bold'))
headache_label.place(relx=0.2,rely=0.65)  

headache_entry=ctk.CTkEntry(window,width=180)
headache_entry.place(relx=0.3,rely=0.65)

jointpain_label=ctk.CTkLabel(window,text='Joint pain (Yes/No)',font=('Arinal',16,'bold'))
jointpain_label.place(relx=0.2,rely=0.75) 

jointpain_entry=ctk.CTkEntry(window,width=180)
jointpain_entry.place(relx=0.3,rely=0.75)

Bleeding_label=ctk.CTkLabel(window,text='Bleeding (Yes/No)',font=('Arinal',16,'bold'))
Bleeding_label.place(relx=0.2,rely=0.85)  

Bleeding_entry=ctk.CTkEntry(window,width=180)
Bleeding_entry.place(relx=0.3,rely=0.85)

drremark_label=ctk.CTkLabel(window,text='Doctor Remark',font=('Arinal',16,'bold'))
drremark_label.place(relx=0.2,rely=0.95)  

drremark_entry=ctk.CTkEntry(window,width=180)
drremark_entry.place(relx=0.3,rely=0.95)

patientnumber_label=ctk.CTkLabel(window,text='Patient Number',font=('Arinal',16,'bold'))
patientnumber_label.place(relx=0.5,rely=0.25)  

patientnumber_entry=ctk.CTkEntry(window,width=180)
patientnumber_entry.place(relx=0.6,rely=0.25)

patientcity_label=ctk.CTkLabel(window,text='Patient City',font=('Arinal',16,'bold'))
patientcity_label.place(relx=0.5,rely=0.35)  

patientcity_entry=ctk.CTkEntry(window,width=180)
patientcity_entry.place(relx=0.6,rely=0.35)

bloodpressure_label=ctk.CTkLabel(window,text='Blood Pressure',font=('Arinal',16,'bold'))
bloodpressure_label.place(relx=0.5,rely=0.45)  

bloodpressure_entry=ctk.CTkEntry(window,width=180)
bloodpressure_entry.place(relx=0.6,rely=0.45)
sampletype_label=ctk.CTkLabel(window,text='Sample Type',font=('Arinal',16,'bold'))
sampletype_label.place(relx=0.5,rely=0.55)  

sampletype_entry=ctk.CTkEntry(window,width=180)
sampletype_entry.place(relx=0.6,rely=0.55)
dengue_label=ctk.CTkLabel(window,text='Dengue Fever Anti-body',font=('Arinal',16,'bold'))
dengue_label.place(relx=0.5,rely=0.65)  

dengue_entry=ctk.CTkEntry(window,width=180)
dengue_entry.place(relx=0.6,rely=0.65)
diabetes_label=ctk.CTkLabel(window,text='Diabetes (Yes/No)',font=('Arinal',16,'bold'))
diabetes_label.place(relx=0.5,rely=0.75)  

diabetes_entry=ctk.CTkEntry(window,width=180)
diabetes_entry.place(relx=0.6,rely=0.75)
vomit_label=ctk.CTkLabel(window,text='Vomiting',font=('Arinal',16,'bold'))
vomit_label.place(relx=0.5,rely=0.35)  

vomit_entry=ctk.CTkEntry(window,width=180)
vomit_entry.place(relx=0.6,rely=0.35)
hemoglobin_label=ctk.CTkLabel(window,text='Hemoglobin (Yes/No)',font=('Arinal',16,'bold'))
hemoglobin_label.place(relx=0.5,rely=0.35)  

hemoglobin_entry=ctk.CTkEntry(window,width=180)
hemoglobin_entry.place(relx=0.6,rely=0.35)

window.title('Medical Report Generator')
window.state('zoomed')
window.resizable(True,False)
window.geometry('2000x720px')
window.mainloop()

# %%
import tkinter as tk
import customtkinter as ctk

window = ctk.CTk()
window.title("Healthy Life Clinic - Medical Report Generator")  # Title for the software
window.geometry("600x600")  # Adjusted for better view

# Configure the appearance
ctk.set_appearance_mode('Dark')
ctk.set_default_color_theme('green')

# Create title label (Hospital Name)
title_label = ctk.CTkLabel(window, text="Healthy Life Clinic", font=("Arial", 45, "bold"))
title_label.place(relx=0.35, rely=0.05)

# Create Labels and Entries with proper alignment using place() method
name_label = ctk.CTkLabel(window, text="Patient Name:",font=("Arial", 15, "bold"))
name_label.place(relx=0.25, rely=0.25,anchor='e')
name_entry = ctk.CTkEntry(window)
name_entry.place(relx=0.255, rely=0.25, anchor="w")

age_label = ctk.CTkLabel(window, text="Age:",font=("Arial", 15, "bold"))
age_label.place(relx=0.25, rely=0.35, anchor="e")
age_entry = ctk.CTkEntry(window)
age_entry.place(relx=0.255, rely=0.35, anchor="w")

gender_label = ctk.CTkLabel(window, text="Gender:",font=("Arial", 15, "bold"))
gender_label.place(relx=0.25, rely=0.45, anchor="e")
gender_entry = ctk.CTkEntry(window)
gender_entry.place(relx=0.255, rely=0.45, anchor="w")

fever_label = ctk.CTkLabel(window, text="Fever (°C):",font=("Arial", 15, "bold"))
fever_label.place(relx=0.25, rely=0.55, anchor="e")
fever_entry = ctk.CTkEntry(window)
fever_entry.place(relx=0.255, rely=0.55, anchor="w")

headache_label = ctk.CTkLabel(window, text="Headache (Yes/No):",font=("Arial", 15, "bold"))
headache_label.place(relx=0.25, rely=0.65, anchor="e")
headache_entry = ctk.CTkEntry(window)
headache_entry.place(relx=0.255, rely=0.65, anchor="w")

joint_pain_label = ctk.CTkLabel(window, text="Joint Pain (Yes/No):",font=("Arial", 15, "bold"))
joint_pain_label.place(relx=0.25, rely=0.75, anchor="e")
joint_pain_entry = ctk.CTkEntry(window)
joint_pain_entry.place(relx=0.255, rely=0.75, anchor="w")

bleeding_label = ctk.CTkLabel(window, text="Bleeding (Yes/No):",font=("Arial", 15, "bold"))
bleeding_label.place(relx=0.25, rely=0.85, anchor="e")
bleeding_entry = ctk.CTkEntry(window)
bleeding_entry.place(relx=0.255, rely=0.85, anchor="w")

remarks_label = ctk.CTkLabel(window, text="Doctor's Remarks:",font=("Arial", 15, "bold"))
remarks_label.place(relx=0.25, rely=0.95, anchor="e")
remarks_entry = ctk.CTkEntry(window)
remarks_entry.place(relx=0.255, rely=0.95, anchor="w")


# Create Labels and Entries with proper alignment using place() method
number_label = ctk.CTkLabel(window, text="Patient Number:",font=("Arial", 15, "bold"))
number_label.place(relx=0.55, rely=0.25, anchor="e")
number_entry = ctk.CTkEntry(window)
number_entry.place(relx=0.555, rely=0.25, anchor="w")

city_label = ctk.CTkLabel(window, text="Patient City:",font=("Arial", 15, "bold"))
city_label.place(relx=0.55, rely=0.35, anchor="e")
city_entry = ctk.CTkEntry(window)
city_entry.place(relx=0.555, rely=0.35, anchor="w")

bp_label = ctk.CTkLabel(window, text="Blood Pressure:",font=("Arial", 15, "bold"))
bp_label.place(relx=0.55, rely=0.45, anchor="e")
bp_entry = ctk.CTkEntry(window)
bp_entry.place(relx=0.555, rely=0.45, anchor="w")

sample_label = ctk.CTkLabel(window, text="Sample Type",font=("Arial", 15, "bold"))
sample_label.place(relx=0.55, rely=0.55, anchor="e")
sample_entry = ctk.CTkEntry(window)
sample_entry.place(relx=0.555, rely=0.55, anchor="w")

Dengue_label = ctk.CTkLabel(window, text="Dengue Fever Anti-boody",font=("Arial", 15, "bold"))
Dengue_label.place(relx=0.55, rely=0.65, anchor="e")
Dengue_entry = ctk.CTkEntry(window)
Dengue_entry.place(relx=0.555, rely=0.65, anchor="w")

diabetes_pain_label = ctk.CTkLabel(window, text="Diabetes (Yes/No):",font=("Arial", 15, "bold"))
diabetes_pain_label.place(relx=0.55, rely=0.75, anchor="e")
diabetes_pain_entry = ctk.CTkEntry(window)
diabetes_pain_entry.place(relx=0.555, rely=0.75, anchor="w")

vomit_label = ctk.CTkLabel(window, text="Vomiting (Yes/No):",font=("Arial", 15, "bold"))
vomit_label.place(relx=0.55, rely=0.85, anchor="e")
vomit_entry = ctk.CTkEntry(window)
vomit_entry.place(relx=0.555, rely=0.85, anchor="w")

Hemoglobin_label = ctk.CTkLabel(window, text="Hemoglobin",font=("Arial", 15, "bold"))
Hemoglobin_label.place(relx=0.55, rely=0.95, anchor="e")
Hemoglobin_entry = ctk.CTkEntry(window)
Hemoglobin_entry.place(relx=0.555, rely=0.95, anchor="w")

submit_button=ctk.CTkButton(window,text='Genrate Report',command=get_report,width=180,height=160)
submit_button.place(relx=0.75,rely=0.45)
from PIL import Image,ImageTk
import os

img_path=os.getcwd()+'\\logo.jpg'

pil_image=Image.open(img_path)
logo_img=ctk.CTkImage(dark_image=pil_image,size=(100,100))
logo_label=ctk.CTkLabel(window,text='',image=logo_img)
logo_label.place(relx=0.25,rely=0.001)
window.state('zoomed')

window.resizable(True, False)  
window.geometry("2024x2024px")
window.mainloop()

# %%
import pandas as pd
import datetime
def get_report():
    name=name_entry.get()
    age=age_entry.get()
    gender=gender_entry.get()
    fever=fever_entry.get()
    headache='Yes' if headache_entry.get().lower()=='yes' else 'No'
    joint_pain= 'Yes' if joint_pain_entry.get().lower()=='yes'   else 'No'
    bleeding= 'Yes' bleeding_entry.get().lower()=='yes'  else 'No'
    remarks= remarks_entry.get()
    number=number_entry.get()
    city=city_entry.get()
    bp=bp_entry.get()
    sample=sample_entry.get()
    dengue=Dengue_entry.get()
    diabetes='Yes' if diabetes_pain_entry.get().lower()=='yes'  else 'No'
    vomit='Yes' if vomit_entry.get().lower()=='yes'  else 'No'
    hem=Hemoglobin_entry.get()
  
    filename = "Medical Data.xlsx"
    if not all([name,age,gender,fever,headache,joint_pain,bleeding,remarks,number,city,bp,sample,dengue,diabetes,vomit,hem]):
        tk.messagebox.showwarning('Input Error','Please fill in all the details')
        return
    curr_dt=datetime.now().str()
    if filename in os.listdir():
        df=pd.read_excel(filename)
        df.loc[len(df)]=[name,age,gender,fever,headache,joint_pain,bleeding,remarks,number,city,bp,sample,dengue,diabetes,vomit,hem]
        df.to_excel('Medical Data.xlsx',index=False)
    else:
        # Prepare data for Excel
        data = {
            "Name": [name],
            "Age": [age],
            "Gender": [gender],
            "Fever (°C)": [fever],
            "Headache": [headache],
            "Joint Pain": [joint_pain],
            "Bleeding": [bleeding],
            "Doctor's Remarks": [remarks],
            "Patient Number": [number],
            "City": [city],
            "Blood Pressure": [bp],
            "Sample Type": [sample],
            "Dengue Fever Antibody": [dengue],
            "Diabetes": [diabetes],
            "Vomiting": [vomit],
            "Hemoglobin": [hem]
        }
        df=pd.DataFrame(data)
        df.to_excel('Medical Data.xlsx',index=False)
        tk.messagebox.showinfo('Success','Information recieved')

# %%
pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from fpdf import FPDF

# %%
class MedicalReport(FPDF)
    def head(self):
        self.image(img_path,10,8,33)
        self.set_font('Arial','B',14)
        self.cell(0,10,'Healthy Life Hospital',border=False,ln=True,align='C')
        self.set_font('Arial','',19)
        self.cell(0,8,'123 Wellness Street, Cityville, State, Zip-398012',border=False,ln=True,align='C)
        
        self.cell(0,8,'Phone: 123 16536126 | Email: info@healthylifehospital.com',border=False,ln=True,ali
        self.ln(10) #position
        self.set_draw_color(169,169,169) #gray color
        self.line_width(0.5) 
        self.line(10,self.get_y(),200,self.get_y())
        self.line(5)
                  
    def Footer(self):
        self.set_y(-15)
        self.set_font('Arial','I',8)
        self.cell(0,10,f' Page No {self.page_no()} | This is a computer generated report')
        
    def patient_details(self,name,age,gender,city):
        self.set_font('Arial','B',14)
        self.sent_fill_color(230,230,230)
        self.cell(0,10,'Personal Details',ln=True,align='L',fill=True)
        self.ln(2)
                  
        self.set_font('Arial','',10)
        self.cell(40,10,'Name',0,10)
        self.cell(0,10,name,0,1)
        self.cell(40,10,'Age',0,10)
        self.cell(0,10,name,0,1)
